# %%
import pandas as pd
df = pd.read_csv('datasets/Admission_Predict.csv', index_col=0)
df.columns = [x.lower().strip() for x in df.columns]
df.head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 5                 314          103                  2  2.0  3.0  8.21
#
#             research  chance of admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.76
# 3                  1             0.72
# 4                  1             0.80
# 5                  0             0.65

# %%
admit_mask = df['chance of admit'] > 0.7
admit_mask.head()
# Out:
# Serial No.
# 1     True
# 2     True
# 3     True
# 4     True
# 5    False
# Name: chance of admit, dtype: bool

# %%
df.where(admit_mask).head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1               337.0        118.0                4.0  4.5  4.5  9.65
# 2               324.0        107.0                4.0  4.0  4.5  8.87
# 3               316.0        104.0                3.0  3.0  3.5  8.00
# 4               322.0        110.0                3.0  3.5  2.5  8.67
# 5                 NaN          NaN                NaN  NaN  NaN   NaN
#
#             research  chance of admit
# Serial No.
# 1                1.0             0.92
# 2                1.0             0.76
# 3                1.0             0.72
# 4                1.0             0.80
# 5                NaN              NaN

# %%
df.where(admit_mask).dropna().head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1               337.0        118.0                4.0  4.5  4.5  9.65
# 2               324.0        107.0                4.0  4.0  4.5  8.87
# 3               316.0        104.0                3.0  3.0  3.5  8.00
# 4               322.0        110.0                3.0  3.5  2.5  8.67
# 6               330.0        115.0                5.0  4.5  3.0  9.34
#
#             research  chance of admit
# Serial No.
# 1                1.0             0.92
# 2                1.0             0.76
# 3                1.0             0.72
# 4                1.0             0.80
# 6                1.0             0.90

# %%
df[df['chance of admit'] > 0.7].head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 6                 330          115                  5  4.5  3.0  9.34
#
#             research  chance of admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.76
# 3                  1             0.72
# 4                  1             0.80
# 6                  1             0.90

# %%
df['gre score']
# Out:
# Serial No.
# 1      337
# 2      324
# 3      316
# 4      322
# 5      314
#       ...
# 396    324
# 397    325
# 398    330
# 399    312
# 400    333
# Name: gre score, Length: 400, dtype: int64

# %%
df[['gre score', 'toefl score']]
# Out:
#             gre score  toefl score
# Serial No.
# 1                 337          118
# 2                 324          107
# 3                 316          104
# 4                 322          110
# 5                 314          103
# ...               ...          ...
# 396               324          110
# 397               325          107
# 398               330          116
# 399               312          103
# 400               333          117
#
# [400 rows x 2 columns]

# %%
df[df['gre score'] > 320].head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 4                 322          110                  3  3.5  2.5  8.67
# 6                 330          115                  5  4.5  3.0  9.34
# 7                 321          109                  3  3.0  4.0  8.20
#
#             research  chance of admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.76
# 4                  1             0.80
# 6                  1             0.90
# 7                  1             0.75

# %%
(df['chance of admit'] > 0.7) & (df['chance of admit'] < 0.9)
# Out:
# Serial No.
# 1      False
# 2       True
# 3       True
# 4       True
# 5      False
#        ...
# 396     True
# 397     True
# 398    False
# 399    False
# 400    False
# Name: chance of admit, Length: 400, dtype: bool

# %%
df['chance of admit'].gt(0.7) & df['chance of admit'].lt(0.9)
# Out:
# Serial No.
# 1      False
# 2       True
# 3       True
# 4       True
# 5      False
#        ...
# 396     True
# 397     True
# 398    False
# 399    False
# 400    False
# Name: chance of admit, Length: 400, dtype: bool

# %%
df['chance of admit'].gt(0.7).lt(0.9)
# Out:
# Serial No.
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
#        ...
# 396    False
# 397    False
# 398    False
# 399     True
# 400    False
# Name: chance of admit, Length: 400, dtype: bool

# %% [markdown]
# # Working with sample data

# %%
# !cat datasets/Admission_Predict.csv | head
# Out:
# Serial No.,GRE Score,TOEFL Score,University Rating,SOP,LOR ,CGPA,Research,Chance of Admit
# 1,337,118,4,4.5,4.5,9.65,1,0.92
# 2,324,107,4,4,4.5,8.87,1,0.76
# 3,316,104,3,3,3.5,8,1,0.72
# 4,322,110,3,3.5,2.5,8.67,1,0.8
# 5,314,103,2,2,3,8.21,0,0.65
# 6,330,115,5,4.5,3,9.34,1,0.9
# 7,321,109,3,3,4,8.2,1,0.75
# 8,308,101,2,3,4,7.9,0,0.68
# 9,302,102,1,2,1.5,8,0,0.5

# %%
import pandas as pd
df = pd.read_csv('datasets/Admission_Predict.csv', index_col=0)
df.columns = [x.lower().strip() for x in df.columns]
df.head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 5                 314          103                  2  2.0  3.0  8.21
#
#             research  chance of admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.76
# 3                  1             0.72
# 4                  1             0.80
# 5                  0             0.65

# %%
gre_mask = df['gre score']>320
gre_mask
# Out:
# Serial No.
# 1       True
# 2       True
# 3      False
# 4       True
# 5      False
#        ...
# 396     True
# 397     True
# 398     True
# 399    False
# 400     True
# Name: gre score, Length: 400, dtype: bool

# %%
toefl_mask = df['toefl score'] > 110

# %%
cgpa_mask = df['cgpa'] > 9.0

# %%
all_mask = df['cgpa'].gt(9.0) & df['toefl score'].gt(110) & df['gre score'].gt(320)

# %%
df.where(all_mask).dropna()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1               337.0        118.0                4.0  4.5  4.5  9.65
# 6               330.0        115.0                5.0  4.5  3.0  9.34
# 13              328.0        112.0                4.0  4.0  4.5  9.10
# 23              328.0        116.0                5.0  5.0  5.0  9.50
# 24              334.0        119.0                5.0  5.0  4.5  9.70
# ...               ...          ...                ...  ...  ...   ...
# 386             335.0        117.0                5.0  5.0  5.0  9.82
# 393             326.0        112.0                4.0  4.0  3.5  9.12
# 395             329.0        111.0                4.0  4.5  4.0  9.23
# 398             330.0        116.0                4.0  5.0  4.5  9.45
# 400             333.0        117.0                4.0  5.0  4.0  9.66
#
#             research  chance of admit
# Serial No.
# 1                1.0             0.92
# ...

# %%
df2 = df.where(all_mask).dropna()

# %%
df2['university rating'].unique()
# Out:
# array([4., 5., 3., 2.])

# %%
df2['serial number'] = df2.index
df2.head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1               337.0        118.0                4.0  4.5  4.5  9.65
# 6               330.0        115.0                5.0  4.5  3.0  9.34
# 13              328.0        112.0                4.0  4.0  4.5  9.10
# 23              328.0        116.0                5.0  5.0  5.0  9.50
# 24              334.0        119.0                5.0  5.0  4.5  9.70
#
#             research  chance of admit  serial number
# Serial No.
# 1                1.0             0.92              1
# 6                1.0             0.90              6
# 13               1.0             0.78             13
# 23               1.0             0.94             23
# 24               1.0             0.95             24

# %%
df2.set_index(['university rating', 'serial number'])
# Out:
#                                  gre score  toefl score  sop  lor  cgpa  \
# university rating serial number
# 4.0               1                  337.0        118.0  4.5  4.5  9.65
# 5.0               6                  330.0        115.0  4.5  3.0  9.34
# 4.0               13                 328.0        112.0  4.0  4.5  9.10
# 5.0               23                 328.0        116.0  5.0  5.0  9.50
#                   24                 334.0        119.0  5.0  4.5  9.70
# ...                                    ...          ...  ...  ...   ...
#                   386                335.0        117.0  5.0  5.0  9.82
# 4.0               393                326.0        112.0  4.0  3.5  9.12
#                   395                329.0        111.0  4.5  4.0  9.23
#                   398                330.0        116.0  5.0  4.5  9.45
#                   400                333.0        117.0  5.0  4.0  9.66
#
#                                  research  chance of admit
# ...

# %%
df2[335.0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 335
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
