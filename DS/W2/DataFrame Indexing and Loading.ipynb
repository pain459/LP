# %%
# !cat datasets/Admission_Predict.csv | head
# Out:
# Serial No.,GRE Score,TOEFL Score,University Rating,SOP,LOR ,CGPA,Research,Chance of Admit
# 1,337,118,4,4.5,4.5,9.65,1,0.92
# 2,324,107,4,4,4.5,8.87,1,0.76
# 3,316,104,3,3,3.5,8,1,0.72
# 4,322,110,3,3.5,2.5,8.67,1,0.8
# 5,314,103,2,2,3,8.21,0,0.65
# 6,330,115,5,4.5,3,9.34,1,0.9
# 7,321,109,3,3,4,8.2,1,0.75
# 8,308,101,2,3,4,7.9,0,0.68
# 9,302,102,1,2,1.5,8,0,0.5

# %%
import pandas as pd
df = pd.read_csv('datasets/Admission_Predict.csv')
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df = pd.read_csv('datasets/Admission_Predict.csv', index_col=0)
df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
# 4                 322          110                  3  3.5   2.5  8.67
# 5                 314          103                  2  2.0   3.0  8.21
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# 2                  1              0.76
# 3                  1              0.72
# 4                  1              0.80
# 5                  0              0.65

# %%
new_df = df.rename(columns={'GRE Score': 'GRE Score', 'TOEFL Score':'TOEFL Score',
                           'University Rating':'University Rating','SOP':'Statement of Purpose',
                           'LOR':'Letter of Recommendation','CGPA':'CGPA', 'Research':'Research',
                           'Chance of Admit':'Chance of Admit'})

# %%
new_df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  Statement of Purpose  \
# Serial No.
# 1                 337          118                  4                   4.5
# 2                 324          107                  4                   4.0
# 3                 316          104                  3                   3.0
# 4                 322          110                  3                   3.5
# 5                 314          103                  2                   2.0
#
#             LOR   CGPA  Research  Chance of Admit
# Serial No.
# 1            4.5  9.65         1              0.92
# 2            4.5  8.87         1              0.76
# 3            3.5  8.00         1              0.72
# 4            2.5  8.67         1              0.80
# 5            3.0  8.21         0              0.65

# %%
new_df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'Statement of Purpose',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
new_df = new_df.rename(columns={'LOR ':'Letter of Recommendation'})
new_df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  Statement of Purpose  \
# Serial No.
# 1                 337          118                  4                   4.5
# 2                 324          107                  4                   4.0
# 3                 316          104                  3                   3.0
# 4                 322          110                  3                   3.5
# 5                 314          103                  2                   2.0
#
#             Letter of Recommendation  CGPA  Research  Chance of Admit
# Serial No.
# 1                                4.5  9.65         1              0.92
# 2                                4.5  8.87         1              0.76
# 3                                3.5  8.00         1              0.72
# 4                                2.5  8.67         1              0.80
# 5                                3.0  8.21         0              0.65

# %%
new_df = new_df.rename(mapper=str.strip, axis=1)
new_df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  Statement of Purpose  \
# Serial No.
# 1                 337          118                  4                   4.5
# 2                 324          107                  4                   4.0
# 3                 316          104                  3                   3.0
# 4                 322          110                  3                   3.5
# 5                 314          103                  2                   2.0
#
#             Letter of Recommendation  CGPA  Research  Chance of Admit
# Serial No.
# 1                                4.5  9.65         1             0.92
# 2                                4.5  8.87         1             0.76
# 3                                3.5  8.00         1             0.72
# 4                                2.5  8.67         1             0.80
# 5                                3.0  8.21         0             0.65

# %%
new_df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'Statement of Purpose',
#        'Letter of Recommendation', 'CGPA', 'Research', 'Chance of Admit'],
#       dtype='object')

# %%
cols = list(df.columns)

# %%
cols
# Out:
# ['GRE Score',
#  'TOEFL Score',
#  'University Rating',
#  'SOP',
#  'LOR ',
#  'CGPA',
#  'Research',
#  'Chance of Admit ']

# %%
cols = [x.lower().strip() for x in cols]
cols
# Out:
# ['gre score',
#  'toefl score',
#  'university rating',
#  'sop',
#  'lor',
#  'cgpa',
#  'research',
#  'chance of admit']

# %%
df.columns = cols

# %%
df.columns
# Out:
# Index(['gre score', 'toefl score', 'university rating', 'sop', 'lor', 'cgpa',
#        'research', 'chance of admit'],
#       dtype='object')

# %%
df.head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 5                 314          103                  2  2.0  3.0  8.21
#
#             research  chance of admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.76
# 3                  1             0.72
# 4                  1             0.80
# 5                  0             0.65

# %% [markdown]
# # Working on sample datasets

# %%
# !cat datasets/country_full.csv | head
# Out:
# name,alpha-2,alpha-3,country-code,iso_3166-2,region,sub-region,intermediate-region,region-code,sub-region-code,intermediate-region-code
# Afghanistan,AF,AFG,004,ISO 3166-2:AF,Asia,Southern Asia,"",142,034,""
# Åland Islands,AX,ALA,248,ISO 3166-2:AX,Europe,Northern Europe,"",150,154,""
# Albania,AL,ALB,008,ISO 3166-2:AL,Europe,Southern Europe,"",150,039,""
# Algeria,DZ,DZA,012,ISO 3166-2:DZ,Africa,Northern Africa,"",002,015,""
# American Samoa,AS,ASM,016,ISO 3166-2:AS,Oceania,Polynesia,"",009,061,""
# Andorra,AD,AND,020,ISO 3166-2:AD,Europe,Southern Europe,"",150,039,""
# Angola,AO,AGO,024,ISO 3166-2:AO,Africa,Sub-Saharan Africa,Middle Africa,002,202,017
# Anguilla,AI,AIA,660,ISO 3166-2:AI,Americas,Latin America and the Caribbean,Caribbean,019,419,029
# Antarctica,AQ,ATA,010,ISO 3166-2:AQ,"","","","","",""

# %%
import pandas as pd

# %%
df = pd.read_csv('datasets/country_full.csv')

# %%
df.head()
# Out:
#              name alpha-2 alpha-3  country-code     iso_3166-2   region  \
# 0     Afghanistan      AF     AFG             4  ISO 3166-2:AF     Asia
# 1   Åland Islands      AX     ALA           248  ISO 3166-2:AX   Europe
# 2         Albania      AL     ALB             8  ISO 3166-2:AL   Europe
# 3         Algeria      DZ     DZA            12  ISO 3166-2:DZ   Africa
# 4  American Samoa      AS     ASM            16  ISO 3166-2:AS  Oceania
#
#         sub-region intermediate-region  region-code  sub-region-code  \
# 0    Southern Asia                 NaN        142.0             34.0
# 1  Northern Europe                 NaN        150.0            154.0
# 2  Southern Europe                 NaN        150.0             39.0
# 3  Northern Africa                 NaN          2.0             15.0
# 4        Polynesia                 NaN          9.0             61.0
#
#    intermediate-region-code
# 0                       NaN
# 1                       NaN
# 2                       NaN
# ...

# %%
headings = list(df.columns)

# %%
headings
# Out:
# ['name',
#  'alpha-2',
#  'alpha-3',
#  'country-code',
#  'iso_3166-2',
#  'region',
#  'sub-region',
#  'intermediate-region',
#  'region-code',
#  'sub-region-code',
#  'intermediate-region-code']

# %%
headings = [x.title() for x in headings]
df.columns = headings
df.head()
# Out:
#              Name Alpha-2 Alpha-3  Country-Code     Iso_3166-2   Region  \
# 0     Afghanistan      AF     AFG             4  ISO 3166-2:AF     Asia
# 1   Åland Islands      AX     ALA           248  ISO 3166-2:AX   Europe
# 2         Albania      AL     ALB             8  ISO 3166-2:AL   Europe
# 3         Algeria      DZ     DZA            12  ISO 3166-2:DZ   Africa
# 4  American Samoa      AS     ASM            16  ISO 3166-2:AS  Oceania
#
#         Sub-Region Intermediate-Region  Region-Code  Sub-Region-Code  \
# 0    Southern Asia                 NaN        142.0             34.0
# 1  Northern Europe                 NaN        150.0            154.0
# 2  Southern Europe                 NaN        150.0             39.0
# 3  Northern Africa                 NaN          2.0             15.0
# 4        Polynesia                 NaN          9.0             61.0
#
#    Intermediate-Region-Code
# 0                       NaN
# 1                       NaN
# 2                       NaN
# ...

# %%
df.rename(columns={'Iso_3166-2 ':'ISO Standards'})
df.head()
# Out:
#              Name Alpha-2 Alpha-3  Country-Code     Iso_3166-2   Region  \
# 0     Afghanistan      AF     AFG             4  ISO 3166-2:AF     Asia
# 1   Åland Islands      AX     ALA           248  ISO 3166-2:AX   Europe
# 2         Albania      AL     ALB             8  ISO 3166-2:AL   Europe
# 3         Algeria      DZ     DZA            12  ISO 3166-2:DZ   Africa
# 4  American Samoa      AS     ASM            16  ISO 3166-2:AS  Oceania
#
#         Sub-Region Intermediate-Region  Region-Code  Sub-Region-Code  \
# 0    Southern Asia                 NaN        142.0             34.0
# 1  Northern Europe                 NaN        150.0            154.0
# 2  Southern Europe                 NaN        150.0             39.0
# 3  Northern Africa                 NaN          2.0             15.0
# 4        Polynesia                 NaN          9.0             61.0
#
#    Intermediate-Region-Code
# 0                       NaN
# 1                       NaN
# 2                       NaN
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Alpha-2', 'Alpha-3', 'Country-Code', 'Iso_3166-2', 'Region',
#        'Sub-Region', 'Intermediate-Region', 'Region-Code', 'Sub-Region-Code',
#        'Intermediate-Region-Code'],
#       dtype='object')

# %%
import numpy as np
df.loc[np.arange(20, 26)]
# Out:
#        Name Alpha-2 Alpha-3  Country-Code     Iso_3166-2    Region  \
# 20  Belarus      BY     BLR           112  ISO 3166-2:BY    Europe
# 21  Belgium      BE     BEL            56  ISO 3166-2:BE    Europe
# 22   Belize      BZ     BLZ            84  ISO 3166-2:BZ  Americas
# 23    Benin      BJ     BEN           204  ISO 3166-2:BJ    Africa
# 24  Bermuda      BM     BMU            60  ISO 3166-2:BM  Americas
# 25   Bhutan      BT     BTN            64  ISO 3166-2:BT      Asia
#
#                          Sub-Region Intermediate-Region  Region-Code  \
# 20                   Eastern Europe                 NaN        150.0
# 21                   Western Europe                 NaN        150.0
# 22  Latin America and the Caribbean     Central America         19.0
# 23               Sub-Saharan Africa      Western Africa          2.0
# 24                 Northern America                 NaN         19.0
# 25                    Southern Asia                 NaN        142.0
#
# ...

# %%
df.loc[np.arange(10, 21)][['Name', 'Region', 'Sub-Region']]
# Out:
#           Name    Region                       Sub-Region
# 10   Argentina  Americas  Latin America and the Caribbean
# 11     Armenia      Asia                     Western Asia
# 12       Aruba  Americas  Latin America and the Caribbean
# 13   Australia   Oceania        Australia and New Zealand
# 14     Austria    Europe                   Western Europe
# 15  Azerbaijan      Asia                     Western Asia
# 16     Bahamas  Americas  Latin America and the Caribbean
# 17     Bahrain      Asia                     Western Asia
# 18  Bangladesh      Asia                    Southern Asia
# 19    Barbados  Americas  Latin America and the Caribbean
# 20     Belarus    Europe                   Eastern Europe

# %%
df.loc[np.arange(10, 21)]
# Out:
#           Name Alpha-2 Alpha-3  Country-Code     Iso_3166-2    Region  \
# 10   Argentina      AR     ARG            32  ISO 3166-2:AR  Americas
# 11     Armenia      AM     ARM            51  ISO 3166-2:AM      Asia
# 12       Aruba      AW     ABW           533  ISO 3166-2:AW  Americas
# 13   Australia      AU     AUS            36  ISO 3166-2:AU   Oceania
# 14     Austria      AT     AUT            40  ISO 3166-2:AT    Europe
# 15  Azerbaijan      AZ     AZE            31  ISO 3166-2:AZ      Asia
# 16     Bahamas      BS     BHS            44  ISO 3166-2:BS  Americas
# 17     Bahrain      BH     BHR            48  ISO 3166-2:BH      Asia
# 18  Bangladesh      BD     BGD            50  ISO 3166-2:BD      Asia
# 19    Barbados      BB     BRB            52  ISO 3166-2:BB  Americas
# 20     Belarus      BY     BLR           112  ISO 3166-2:BY    Europe
#
#                          Sub-Region Intermediate-Region  Region-Code  \
# ...

# %%
# !cat datasets/timezone.csv | head
# Out:
# Value,Label,Group
# Africa/Abidjan,Abidjan,Africa
# Africa/Accra,Accra,Africa
# Africa/Addis_Ababa,Addis Ababa,Africa
# Africa/Algiers,Algiers,Africa
# Africa/Asmara,Asmara,Africa
# Africa/Bamako,Bamako,Africa
# Africa/Bangui,Bangui,Africa
# Africa/Banjul,Banjul,Africa
# Africa/Bissau,Bissau,Africa

# %%
import pandas as pd
timezone_df = pd.read_csv('datasets/timezone.csv')
timezone_df.head()
# Out:
#                 Value        Label   Group
# 0      Africa/Abidjan      Abidjan  Africa
# 1        Africa/Accra        Accra  Africa
# 2  Africa/Addis_Ababa  Addis Ababa  Africa
# 3      Africa/Algiers      Algiers  Africa
# 4       Africa/Asmara       Asmara  Africa

# %%
timezone_df.iloc[0]
# Out:
# Value    Africa/Abidjan
# Label           Abidjan
# Group            Africa
# Name: 0, dtype: object
