# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("salaries.csv")
df.head()
# Out:
#    work_year experience_level employment_type             job_title  salary  \
# 0       2020               EN              FT   Azure Data Engineer  100000
# 1       2020               EN              CT    Staff Data Analyst   60000
# 2       2020               SE              FT  Staff Data Scientist  164000
# 3       2020               EN              FT          Data Analyst   42000
# 4       2020               EX              FT        Data Scientist  300000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         100000                 MU             0
# 1             CAD          44753                 CA            50
# 2             USD         164000                 US            50
# 3             EUR          47899                 DE             0
# 4             USD         300000                 US           100
#
#   company_location company_size
# 0               MU            S
# 1               CA            L
# ...

# %%
df.drop(columns=["salary", "salary_currency"], inplace=True)
df.head()
# Out:
#    work_year experience_level employment_type             job_title  \
# 0       2020               EN              FT   Azure Data Engineer
# 1       2020               EN              CT    Staff Data Analyst
# 2       2020               SE              FT  Staff Data Scientist
# 3       2020               EN              FT          Data Analyst
# 4       2020               EX              FT        Data Scientist
#
#    salary_in_usd employee_residence  remote_ratio company_location  \
# 0         100000                 MU             0               MU
# 1          44753                 CA            50               CA
# 2         164000                 US            50               US
# 3          47899                 DE             0               DE
# 4         300000                 US           100               US
#
#   company_size
# 0            S
# 1            L
# 2            M
# 3            L
# 4            L

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37234 entries, 0 to 37233
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           37234 non-null  int64
#  1   experience_level    37234 non-null  object
#  2   employment_type     37234 non-null  object
#  3   job_title           37234 non-null  object
#  4   salary_in_usd       37234 non-null  int64
#  5   employee_residence  37234 non-null  object
#  6   remote_ratio        37234 non-null  int64
#  7   company_location    37234 non-null  object
#  8   company_size        37234 non-null  object
# dtypes: int64(3), object(6)
# memory usage: 2.6+ MB

# %%
df.describe(include="all")
# Out:
#            work_year experience_level employment_type       job_title  \
# count   37234.000000            37234           37234           37234
# unique           NaN                4               4             215
# top              NaN               SE              FT  Data Scientist
# freq             NaN            22523           37121            7448
# mean     2023.656443              NaN             NaN             NaN
# std         0.611469              NaN             NaN             NaN
# min      2020.000000              NaN             NaN             NaN
# 25%      2023.000000              NaN             NaN             NaN
# 50%      2024.000000              NaN             NaN             NaN
# 75%      2024.000000              NaN             NaN             NaN
# max      2024.000000              NaN             NaN             NaN
#
#         salary_in_usd employee_residence  remote_ratio company_location  \
# ...

# %%
df['work_year'].value_counts()
# Out:
# work_year
# 2024    26761
# 2023     8522
# 2022     1658
# 2021      218
# 2020       75
# Name: count, dtype: int64

# %%
df['work_year'].describe()
# Out:
# count    37234.000000
# mean      2023.656443
# std          0.611469
# min       2020.000000
# 25%       2023.000000
# 50%       2024.000000
# 75%       2024.000000
# max       2024.000000
# Name: work_year, dtype: float64

# %%
df['job_title'].value_counts()
# Out:
# job_title
# Data Scientist                      7448
# Data Engineer                       6103
# Data Analyst                        4351
# Machine Learning Engineer           3990
# Software Engineer                   2935
#                                     ...
# AI Software Development Engineer       1
# Applied Research Scientist             1
# CRM Data Analyst                       1
# Big Data Developer                     1
# Quantitative Research Analyst          1
# Name: count, Length: 215, dtype: int64

# %%
sns.barplot(x=df['work_year'].value_counts().index, y=df['work_year'].value_counts().values, palette='viridis')
# Out:
# /tmp/ipykernel_4632/3052752157.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['work_year'].value_counts().index, y=df['work_year'].value_counts().values, palette='viridis')
# <Axes: xlabel='work_year'>

# %%
df['experience_level'].value_counts().plot(kind="pie", autopct="%1.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df['employment_type'].value_counts()
# Out:
# employment_type
# FT    37121
# PT       52
# CT       47
# FL       14
# Name: count, dtype: int64

# %%
sns.barplot(x=df['employment_type'].value_counts().index, y=df['employment_type'].value_counts().values, palette='viridis')
# Out:
# /tmp/ipykernel_4632/1007320438.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['employment_type'].value_counts().index, y=df['employment_type'].value_counts().values, palette='viridis')
# <Axes: xlabel='employment_type'>

# %%
df['job_title'].value_counts().head(10)
# Out:
# job_title
# Data Scientist               7448
# Data Engineer                6103
# Data Analyst                 4351
# Machine Learning Engineer    3990
# Software Engineer            2935
# Research Scientist           1569
# Applied Scientist             881
# Data Architect                807
# Analytics Engineer            758
# Research Engineer             708
# Name: count, dtype: int64

# %%
sns.barplot(x=df['job_title'].value_counts().head(10).index, y=df['job_title'].value_counts().head(10).values, palette='turbo')
plt.title("top 10 jobs")
plt.xticks(rotation=90)
plt.show()
# Out:
# /tmp/ipykernel_4632/1525971173.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['job_title'].value_counts().head(10).index, y=df['job_title'].value_counts().head(10).values, palette='turbo')

# %%
plt.colormaps()
# Out:
# ['magma',
#  'inferno',
#  'plasma',
#  'viridis',
#  'cividis',
#  'twilight',
#  'twilight_shifted',
#  'turbo',
#  'Blues',
#  'BrBG',
#  'BuGn',
#  'BuPu',
#  'CMRmap',
#  'GnBu',
#  'Greens',
#  'Greys',
#  'OrRd',
#  'Oranges',
#  'PRGn',
#  'PiYG',
#  'PuBu',
#  'PuBuGn',
#  'PuOr',
#  'PuRd',
#  'Purples',
#  'RdBu',
#  'RdGy',
#  'RdPu',
#  'RdYlBu',
#  'RdYlGn',
#  'Reds',
#  'Spectral',
#  'Wistia',
#  'YlGn',
#  'YlGnBu',
#  'YlOrBr',
#  'YlOrRd',
#  'afmhot',
#  'autumn',
#  'binary',
#  'bone',
#  'brg',
#  'bwr',
#  'cool',
#  'coolwarm',
#  'copper',
#  'cubehelix',
#  'flag',
#  'gist_earth',
#  'gist_gray',
#  'gist_heat',
#  'gist_ncar',
#  'gist_rainbow',
#  'gist_stern',
#  'gist_yarg',
#  'gnuplot',
#  'gnuplot2',
#  'gray',
#  'hot',
#  'hsv',
#  'jet',
#  'nipy_spectral',
#  'ocean',
#  'pink',
#  'prism',
#  'rainbow',
#  'seismic',
#  'spring',
#  'summer',
#  'terrain',
#  'winter',
#  'Accent',
#  'Dark2',
#  'Paired',
#  'Pastel1',
#  'Pastel2',
# ...

# %%
df['salary_in_usd'].describe()
# Out:
# count     37234.000000
# mean     160540.603105
# std       72679.876280
# min       15000.000000
# 25%      110000.000000
# 50%      150000.000000
# 75%      200000.000000
# max      800000.000000
# Name: salary_in_usd, dtype: float64

# %%
sns.histplot(df['salary_in_usd'], kde=True)
# Out:
# <Axes: xlabel='salary_in_usd', ylabel='Count'>

# %%
df['employee_residence'].value_counts().head(10)
# Out:
# employee_residence
# US    33755
# GB     1121
# CA     1113
# ES      143
# DE      142
# IN       97
# FR       84
# AU       84
# NL       61
# BR       35
# Name: count, dtype: int64

# %%
sns.barplot(x=df['employee_residence'].value_counts().head(10).index, y=df['employee_residence'].value_counts().head(10).values, palette='turbo')
plt.title("top 10 countries")
plt.xticks(rotation=90)
plt.show()
# Out:
# /tmp/ipykernel_4632/529427994.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['employee_residence'].value_counts().head(10).index, y=df['employee_residence'].value_counts().head(10).values, palette='turbo')

# %%
df['employee_residence'].value_counts().head()
# Out:
# employee_residence
# US    33755
# GB     1121
# CA     1113
# ES      143
# DE      142
# Name: count, dtype: int64

# %%
df['remote_ratio'].value_counts().plot(kind="pie",autopct="%1.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
sns.barplot(x=df['company_location'].value_counts().head().index,y=df['company_location'].value_counts().head().values,palette= 'turbo')
plt.title("top 5 locations")
plt.xticks(rotation=90)
plt.show()
# Out:
# /tmp/ipykernel_4632/2214497790.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['company_location'].value_counts().head().index,y=df['company_location'].value_counts().head().values,palette= 'turbo')

# %%
df['company_size'].value_counts().plot(kind="pie",autopct="%1.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
pd.crosstab(df['work_year'],df['experience_level'],).plot(kind="bar")
# Out:
# <Axes: xlabel='work_year'>

# %%
pd.crosstab(df['work_year'],df['employment_type'])
# Out:
# employment_type  CT  FL     FT  PT
# work_year
# 2020              3   1     69   2
# 2021              3   3    208   4
# 2022              4   4   1644   6
# 2023             10   4   8505   3
# 2024             27   2  26695  37

# %%
pd.crosstab(df['work_year'],['job_title'])
# Out:
# col_0      job_title
# work_year
# 2020              75
# 2021             218
# 2022            1658
# 2023            8522
# 2024           26761

# %%
df.groupby('work_year')['salary_in_usd'].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='work_year'>

# %%
pd.crosstab(df['work_year'],df['remote_ratio'])
# Out:
# remote_ratio    0    50    100
# work_year
# 2020             18   21    36
# 2021             29   73   116
# 2022            709   62   887
# 2023           5775   73  2674
# 2024          21937   28  4796

# %%
pd.crosstab(df["work_year"],df["company_size"]).plot(kind="bar")
# Out:
# <Axes: xlabel='work_year'>

# %%
df["experience_level"].unique()
# Out:
# array(['EN', 'SE', 'EX', 'MI'], dtype=object)

# %%
sns.barplot(x="experience_level", y="salary_in_usd" , data=df ,palette="cool")
plt.grid(True, axis='y', linestyle='--', alpha=0.75)
plt.title("Average Salary (USD) with Experience level", fontsize=16, fontweight='bold')
plt.xlabel("Experience_level", fontsize=14)
plt.ylabel("Average Salary in USD", fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()
# Out:
# /tmp/ipykernel_4632/3500827139.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="experience_level", y="salary_in_usd" , data=df ,palette="cool")

# %%
pd.crosstab(df["experience_level"],df["remote_ratio"].sort_index()).plot(kind="bar")
# Out:
# <Axes: xlabel='experience_level'>

# %%
pd.crosstab(df["company_size"],df["experience_level"]).plot(kind="bar")
# Out:
# <Axes: xlabel='company_size'>

# %%
plt.figure(figsize=(8.75, 6.5))
sns.barplot(x="employment_type", y="salary_in_usd" , data=df ,palette="YlGnBu")
plt.grid(True, axis='y', linestyle='--', alpha=0.75)
plt.title("Average Salary (USD) with Employment type", fontsize=16, fontweight='bold')
plt.xlabel("Employment_type", fontsize=14)
plt.ylabel("Average Salary in USD", fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()
# Out:
# /tmp/ipykernel_4632/961707815.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="employment_type", y="salary_in_usd" , data=df ,palette="YlGnBu")

# %%
pd.crosstab(df["employment_type"],df["remote_ratio"]).plot(kind="bar")
# Out:
# <Axes: xlabel='employment_type'>

# %%
pd.crosstab(df["company_size"],df["employment_type"]).plot(kind="bar")
# Out:
# <Axes: xlabel='company_size'>

# %%
plt.figure(figsize=(9, 6.5))
sns.barplot(x="remote_ratio", y="salary_in_usd", data=df, palette="viridis")  

plt.title("Average Salary (USD) by Remote Ratio", fontsize=16, fontweight='bold')
plt.xlabel("Remote Ratio", fontsize=14)
plt.ylabel("Average Salary in USD", fontsize=14)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.grid(True, axis='y', linestyle='--', alpha=0.7)

plt.show()
# Out:
# /tmp/ipykernel_4632/2624854338.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="remote_ratio", y="salary_in_usd", data=df, palette="viridis")

# %%
plt.figure(figsize=(10, 6.75))
sns.barplot(x="company_size", y="salary_in_usd", data=df, palette="winter")  

plt.title("Average Salary (USD) with company size", fontsize=16, fontweight='bold')
plt.xlabel("company_size", fontsize=14)
plt.ylabel("Average Salary in USD", fontsize=14)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.grid(True, axis='y', linestyle='--', alpha=0.7)

plt.show()
# Out:
# /tmp/ipykernel_4632/2764547864.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="company_size", y="salary_in_usd", data=df, palette="winter")

# %%
pd.crosstab(df["company_size"],df["remote_ratio"]).plot(kind="bar")
# Out:
# <Axes: xlabel='company_size'>

# %%
sns.pairplot(df)

# %%
def summary(df):
    print(f'data shape: {df.shape}')
    summ = pd.DataFrame(df.dtypes, columns=['Data Type'])
    summ['Missing#'] = df.isna().sum()
    summ['Missing%'] = (df.isna().sum())/len(df)
    summ['Dups'] = df.duplicated().sum()
    summ['Uniques'] = df.nunique().values
    summ['Count'] = df.count().values
    desc = pd.DataFrame(df.describe(include='all').transpose())
    summ['Min'] = desc['min'].values
    summ['Max'] = desc['max'].values
    summ['Average'] = desc['mean'].values
    summ['Standard Deviation'] = desc['std'].values
    summ['First Value'] = df.loc[0].values
    summ['Second Value'] = df.loc[1].values
    summ['Third Value'] = df.loc[2].values

    display(summ)

summary(df)
# Out:
# data shape: (37234, 9)
#                    Data Type  Missing#  Missing%   Dups  Uniques  Count  \
# work_year              int64         0       0.0  18189        5  37234
# experience_level      object         0       0.0  18189        4  37234
# employment_type       object         0       0.0  18189        4  37234
# job_title             object         0       0.0  18189      215  37234
# salary_in_usd          int64         0       0.0  18189     4924  37234
# employee_residence    object         0       0.0  18189       91  37234
# remote_ratio           int64         0       0.0  18189        3  37234
# company_location      object         0       0.0  18189       81  37234
# company_size          object         0       0.0  18189        3  37234
#
#                         Min       Max        Average Standard Deviation  \
# work_year            2020.0    2024.0    2023.656443           0.611469
# experience_level        NaN       NaN            NaN                NaN
# ...

# %%
numeric_df = df.select_dtypes(include=[float , int])
corr = numeric_df.corr()
corr
# Out:
#                work_year  salary_in_usd  remote_ratio
# work_year       1.000000       0.122510     -0.232403
# salary_in_usd   0.122510       1.000000     -0.089091
# remote_ratio   -0.232403      -0.089091      1.000000

# %%
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >
